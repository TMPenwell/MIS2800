# %% [markdown]
# <a href="https://colab.research.google.com/github/TMPenwell/MIS2800/blob/main/MIS2800_IC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# %%
conn = sqlite3.connect('mis2800_practice.db')

# %%
conn execute(""" CREATE TABLE students(
    student_id INTEGER PRIMARY KEY,
    first_name TEXT,
    last_name TEXT,
    grade INTEGER
)
))
# Out:
#   File "/tmp/ipython-input-2013290197.py", line 1
#     conn execute(""" CREATE TABLE students(
#                  ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 7)

# %%
conn execute("""
CREATE TABLE students (
  student_id INTEGER PRIMARY KEY,
  first_name TEXT,
  last_name TEXT,
  gpa REAL
  ) STRICT;
  """
)
# Out:
#   File "/tmp/ipython-input-2233384174.py", line 1
#     conn execute("""
#          ^
# SyntaxError: invalid syntax

# %%
conn.execute("""
CREATE TABLE students (
  student_id INTEGER PRIMARY KEY,
  first_name TEXT,
  last_name TEXT,
  gpa REAL
  ) STRICT;
  """
)

# %%
conn.execute("""
INSERT INTO students (name, gpa)
VALUES ('Alic', 3.8),
      ('Bob', 3.2),
      ('Charlie', 3.9);
      """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-3505978005.py in <cell line: 0>()
# ----> 1 conn.execute("""
#       2 INSERT INTO students (name, gpa)
#       3 VALUES ('Alic', 3.8),
#       4       ('Bob', 3.2),
#       5       ('Charlie', 3.9);
#
# OperationalError: table students has no column named name

# %%
conn.execute ("""
INSERT INTO students (first_name, last_name, gpa)
VALUES ('Taylor', 'Swift', 3.5),
  ('Joe', 'Burrow', 3.8),
  ('Joe', 'Falco', 3.9);
  """)

# %%
conn.execute("""SELECT * FROM students""")
# Out:
#   File "/tmp/ipython-input-206492156.py", line 1
#     conn.execute(SELECT * FROM students)
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
conn.execute("""SELECT * FROM students""")

# %%
cursor = conn.execute("""SELECT * FROM students""")
results = cursor.fetchall()
for row in results:
    print(row)
# Out:
# (1, 'Taylor', 'Swift', 3.5)
# (2, 'Joe', 'Burrow', 3.8)
# (3, 'Joe', 'Falco', 3.9)
