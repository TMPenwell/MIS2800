# %% [markdown]
# <a href="https://colab.research.google.com/github/TMPenwell/MIS2800/blob/main/IC_20260202_StarterFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating, Filtering, and Sorting
#
# Run each block to set up the file for IC activities.
#
# This exercise imports the necessary libraries to integrate Python and SQLite. We will use the SQLite "Magic" syntax (`%%sql`), which allows us to write SQL queries directly in the cells without wrapping them in Python code.

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
print("pretty table installed")
# this installation run a series of lines of code below.
# Out:
# ...
# pretty table installed

# %%
# Install the SQL extension (not in sources, but required for magics)
# !pip install ipython-sql
print("ipython sql installed")
# this installation will run a series of lines of code below.
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'SuperBowlMarketing2026.db'
conn = sqlite3.connect('SuperBowlMarketing2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///SuperBowlMarketing2026.db
